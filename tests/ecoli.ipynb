# %% [markdown]
# # **Results for Ecoli dataset**

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))
from comparator import *

# %% [markdown]
# ## Sampling rate = 0.5

# %%
comparator = Comparator(dataset_names=["ecoli"],
                        results_path="../results_csv/ecoli.csv",
                        n_trees=100,
                        iterations=100)
comparator.compute()
# Out:
# =========================================================================
# =========================     START COMPUTING     =======================
# =========================================================================
#
# Datasets: ['ecoli']
# Mode: both
# Oversampling strategies: ['random', 'SMOTE', 'BorderlineSMOTE', 'ADASYN']
# Metrics: ['precision', 'recall', 'f1-score', 'accuracy', 'auc', 'g-mean']
# Iterations: 100
# Number of trees: 100
#
#
#  + DATASET: ecoli
#
# -=-=-=-=-=-=   BAGGING   =-=-=-=-=-
# random - bagging |██████████████████████████████| 100.0% Complete
# SMOTE - bagging |██████████████████████████████| 100.0% Complete
# BorderlineSMOTE - bagging |██████████████████████████████| 100.0% Complete
# ADASYN - bagging |██████████████████████████████| 100.0% Complete
#
# -=-=-=-=-=-=   AUGMENTATION   =-=-=-=-=-
# random - augmentation |██████████████████████████████| 100.0% Complete
# SMOTE - augmentation |██████████████████████████████| 100.0% Complete
# BorderlineSMOTE - augmentation |██████████████████████████████| 100.0% Complete
# ADASYN - augmentation |██████████████████████████████| 100.0% Complete
#
# -=-=-=-=-=-=   BASELINE   =-=-=-=-=-
# baseline |██████████████████████████████| 100.0% Complete
#
# =========================================================================
# ==================     COMPUTING ENDED SUCCESSFULLY      ================
# =========================================================================

# %%
comparator.summary()
# Out:
#  =========================================================================
# =========================         SUMMARY         =======================
# =========================================================================
#
# *****  DATASET: ecoli
#
# *****  oversampling rate: 0.5

# %% [markdown]
# ### Sampling rate = 0.3

# %%
comparator1 = Comparator(
    dataset_names=["ecoli"],
    results_path="../results_csv/ecoli1.csv",
    sampling_rate=0.3,
    n_trees=100,
    iterations=100,
)
comparator1.compute()
comparator1.summary()
# Out:
# =========================================================================
# =========================     START COMPUTING     =======================
# =========================================================================
#
# Datasets: ['ecoli']
# Mode: both
# Oversampling strategies: ['random', 'SMOTE', 'BorderlineSMOTE', 'ADASYN']
# Metrics: ['precision', 'recall', 'f1-score', 'accuracy', 'auc', 'g-mean']
# Iterations: 100
# Number of trees: 100
#
#
#  + DATASET: ecoli
#
# -=-=-=-=-=-=   BAGGING   =-=-=-=-=-
# random - bagging |██████████████████████████████| 100.0% Complete
# SMOTE - bagging |██████████████████████████████| 100.0% Complete
# BorderlineSMOTE - bagging |██████████████████████████████| 100.0% Complete
# ADASYN - bagging |██████████████████████████████| 100.0% Complete
#
# -=-=-=-=-=-=   AUGMENTATION   =-=-=-=-=-
# random - augmentation |██████████████████████████████| 100.0% Complete
# SMOTE - augmentation |██████████████████████████████| 100.0% Complete
# BorderlineSMOTE - augmentation |██████████████████████████████| 100.0% Complete
# ADASYN - augmentation |██████████████████████████████| 100.0% Complete
#
# -=-=-=-=-=-=   BASELINE   =-=-=-=-=-
# baseline |██████████████████████████████| 100.0% Complete
#
# =========================================================================
# ==================     COMPUTING ENDED SUCCESSFULLY      ================
# =========================================================================
#
#
#  =========================================================================
# =========================         SUMMARY         =======================
# =========================================================================
#
# *****  DATASET: ecoli
#
# *****  oversampling rate: 0.3

# %%
comparator.summary(plot_data=True, plot_metrix=False)
# Out:
#  =========================================================================
# =========================         SUMMARY         =======================
# =========================================================================
#
# *****  DATASET: ecoli
#
# *****  oversampling rate: 0.5
# Class -1 has 240 points.
# Class 1 has 28 points.
#
#
#
#
# +++ random - bagging
# Class 0 has 240 original samples and 0 synthetic samples after random bagging.
# Class 1 has 28 original samples and 92 synthetic samples after random bagging.
#
#
#              min_precision avg_precision max_precision std_precision
#           -1       0.8906       0.9417       0.9833       0.0193
#            1       0.0000       0.7295       1.0000       0.2104
#
#                min_recall   avg_recall   max_recall   std_recall
#           -1       0.9180       0.9777       1.0000       0.0196
#            1       0.0000       0.4686       0.8571       0.1862
#
#              min_f1-score avg_f1-score max_f1-score std_f1-score
#           -1       0.9120       0.9592       0.9839       0.0128
#            1       0.0000       0.5487       0.8333       0.1708
#
#                       min          avg          max          std
#  precision :       0.4453       0.8356       0.9841       0.1089
#
#                       min          avg          max          std
#     recall :       0.4672       0.7231       0.9122       0.0918
#
#                       min          avg          max          std
#   f1-score :       0.4560       0.7539       0.9086       0.0909
#
#                       min          avg          max          std
#   accuracy :       0.8382       0.9253       0.9706       0.0234
#
#                       min          avg          max          std
#        auc :       0.8162       0.9294       1.0000       0.0460
#
#                       min          avg          max          std
#     g-mean :       0.0000       0.6575       0.9105       0.1592
#
#
#
# +++ SMOTE - bagging
# Class 0 has 247 original samples and 0 synthetic samples after SMOTE bagging.
# Class 1 has 21 original samples and 102 synthetic samples after SMOTE bagging.
#
#
#              min_precision avg_precision max_precision std_precision
#           -1       0.9032       0.9591       1.0000       0.0205
#            1       0.1667       0.6704       1.0000       0.1627
#
#                min_recall   avg_recall   max_recall   std_recall
#           -1       0.8689       0.9598       1.0000       0.0263
#            1       0.1429       0.6386       1.0000       0.1910
#
#              min_f1-score avg_f1-score max_f1-score std_f1-score
#           -1       0.9106       0.9591       0.9839       0.0152
#            1       0.1538       0.6344       0.8750       0.1442
#
#                       min          avg          max          std
#  precision :       0.5349       0.8148       0.9841       0.0844
#
#                       min          avg          max          std
#     recall :       0.5304       0.7992       0.9836       0.0932
#
#                       min          avg          max          std
#   f1-score :       0.5322       0.7968       0.9292       0.0784
#
#                       min          avg          max          std
#   accuracy :       0.8382       0.9268       0.9706       0.0268
#
#                       min          avg          max          std
#        auc :       0.8314       0.9458       0.9977       0.0354
#
#                       min          avg          max          std
#     g-mean :       0.3621       0.7718       0.9835       0.1275
#
#
#
# +++ BorderlineSMOTE - bagging
# Class 0 has 250 original samples and 0 synthetic samples after BorderlineSMOTE bagging.
# Class 1 has 18 original samples and 107 synthetic samples after BorderlineSMOTE bagging.
#
#
#              min_precision avg_precision max_precision std_precision
#           -1       0.9062       0.9544       1.0000       0.0196
#            1       0.2500       0.6669       1.0000       0.1701
#
#                min_recall   avg_recall   max_recall   std_recall
#           -1       0.9016       0.9620       1.0000       0.0246
#            1       0.1429       0.5957       1.0000       0.1828
#
#              min_f1-score avg_f1-score max_f1-score std_f1-score
#           -1       0.9180       0.9579       0.9919       0.0151
#            1       0.1818       0.6108       0.9231       0.1489
#
#                       min          avg          max          std
#  precision :       0.5781       0.8107       0.9919       0.0886
#
#                       min          avg          max          std
#     recall :       0.5468       0.7788       0.9672       0.0904
#
#                       min          avg          max          std
#   f1-score :       0.5549       0.7843       0.9575       0.0809
#
#                       min          avg          max          std
#   accuracy :       0.8529       0.9243       0.9853       0.0269
#
#                       min          avg          max          std
#        auc :       0.8220       0.9407       1.0000       0.0397
#
#                       min          avg          max          std
#     g-mean :       0.3686       0.7465       0.9667       0.1240
#
#
#
# +++ ADASYN - bagging
# Class 0 has 239 original samples and 0 synthetic samples after ADASYN bagging.
# Class 1 has 29 original samples and 97 synthetic samples after ADASYN bagging.
#
#
#              min_precision avg_precision max_precision std_precision
#           -1       0.9062       0.9585       1.0000       0.0193
#            1       0.2500       0.6601       1.0000       0.1562
#
#                min_recall   avg_recall   max_recall   std_recall
#           -1       0.8689       0.9593       1.0000       0.0258
#            1       0.1429       0.6343       1.0000       0.1774
#
#              min_f1-score avg_f1-score max_f1-score std_f1-score
#           -1       0.9138       0.9586       0.9919       0.0156
#            1       0.1818       0.6333       0.9333       0.1397
#
#                       min          avg          max          std
#  precision :       0.5781       0.8093       0.9919       0.0825
#
#                       min          avg          max          std
#     recall :       0.5468       0.7968       0.9918       0.0879
#
#                       min          avg          max          std
#   f1-score :       0.5549       0.7960       0.9625       0.0767
#
#                       min          avg          max          std
#   accuracy :       0.8529       0.9259       0.9853       0.0275
#
#                       min          avg          max          std
#        auc :       0.8513       0.9413       1.0000       0.0408
#
#                       min          avg          max          std
#     g-mean :       0.3686       0.7712       0.9918       0.1151
#
#
# +++ random - augmentation +++
# Forest index: 400
# Class -1 has 240 original points and 0 synthetic points after random augmentation.
# Class 1 has 28 original points and 92 synthetic points after random augmentation.
#
#
#              min_precision avg_precision max_precision std_precision
#           -1       0.9062       0.9537       1.0000       0.0194
#            1       0.2500       0.6565       1.0000       0.1788
#
#                min_recall   avg_recall   max_recall   std_recall
#           -1       0.8361       0.9597       1.0000       0.0292
#            1       0.1429       0.5900       1.0000       0.1812
#
#              min_f1-score avg_f1-score max_f1-score std_f1-score
#           -1       0.8870       0.9563       0.9919       0.0166
#            1       0.1818       0.6024       0.9231       0.1456
#
#                       min          avg          max          std
#  precision :       0.5781       0.8051       0.9919       0.0928
#
#                       min          avg          max          std
#     recall :       0.5468       0.7748       0.9836       0.0888
#
#                       min          avg          max          std
#   f1-score :       0.5549       0.7793       0.9575       0.0796
#
#                       min          avg          max          std
#   accuracy :       0.8088       0.9216       0.9853       0.0289
#
#                       min          avg          max          std
#        auc :       0.8326       0.9324       0.9871       0.0404
#
#                       min          avg          max          std
#     g-mean :       0.3686       0.7416       0.9835       0.1235
#
#
# +++ SMOTE - augmentation +++
# Forest index: 500
# Class -1 has 240 original points and 0 synthetic points after SMOTE augmentation.
# Class 1 has 28 original points and 92 synthetic points after SMOTE augmentation.
#
#
#              min_precision avg_precision max_precision std_precision
#           -1       0.9091       0.9592       1.0000       0.0184
#            1       0.3750       0.6279       1.0000       0.1427
#
#                min_recall   avg_recall   max_recall   std_recall
#           -1       0.8689       0.9520       1.0000       0.0262
#            1       0.1429       0.6429       1.0000       0.1693
#
#              min_f1-score avg_f1-score max_f1-score std_f1-score
#           -1       0.9217       0.9552       0.9836       0.0142
#            1       0.2222       0.6191       0.8571       0.1197
#
#                       min          avg          max          std
#  precision :       0.6542       0.7936       0.9766       0.0737
#
#                       min          avg          max          std
#     recall :       0.5632       0.7974       0.9754       0.0817
#
#                       min          avg          max          std
#   f1-score :       0.5836       0.7872       0.9204       0.0657
#
#                       min          avg          max          std
#   accuracy :       0.8676       0.9201       0.9706       0.0248
#
#                       min          avg          max          std
#        auc :       0.7342       0.9380       1.0000       0.0451
#
#                       min          avg          max          std
#     g-mean :       0.3749       0.7743       0.9751       0.1063
#
#
# +++ BorderlineSMOTE - augmentation +++
# Forest index: 600
# Class -1 has 240 original points and 0 synthetic points after BorderlineSMOTE augmentation.
# Class 1 has 28 original points and 92 synthetic points after BorderlineSMOTE augmentation.
#
#
#              min_precision avg_precision max_precision std_precision
#           -1       0.9167       0.9555       1.0000       0.0205
#            1       0.2500       0.5965       0.8750       0.1378
#
#                min_recall   avg_recall   max_recall   std_recall
#           -1       0.8852       0.9502       0.9836       0.0250
#            1       0.2857       0.6100       1.0000       0.1848
#
#              min_f1-score avg_f1-score max_f1-score std_f1-score
#           -1       0.9076       0.9525       0.9917       0.0156
#            1       0.2667       0.5909       0.9333       0.1368
#
#                       min          avg          max          std
#  precision :       0.5833       0.7760       0.9375       0.0743
#
#                       min          avg          max          std
#     recall :       0.5937       0.7801       0.9918       0.0917
#
#                       min          avg          max          std
#   f1-score :       0.5879       0.7717       0.9625       0.0752
#
#                       min          avg          max          std
#   accuracy :       0.8382       0.9151       0.9853       0.0276
#
#                       min          avg          max          std
#        auc :       0.7998       0.9296       0.9977       0.0464
#
#                       min          avg          max          std
#     g-mean :       0.5076       0.7519       0.9918       0.1179
#
#
# +++ ADASYN - augmentation +++
# Forest index: 700
# Class -1 has 240 original points and 0 synthetic points after ADASYN augmentation.
# Class 1 has 28 original points and 99 synthetic points after ADASYN augmentation.
#
#
#              min_precision avg_precision max_precision std_precision
#           -1       0.9016       0.9612       1.0000       0.0200
#            1       0.1429       0.5643       1.0000       0.1398
#
#                min_recall   avg_recall   max_recall   std_recall
#           -1       0.8361       0.9367       1.0000       0.0314
#            1       0.1429       0.6657       1.0000       0.1784
#
#              min_f1-score avg_f1-score max_f1-score std_f1-score
#           -1       0.9016       0.9484       0.9839       0.0178
#            1       0.1429       0.5985       0.8750       0.1285
#
#                       min          avg          max          std
#  precision :       0.5222       0.7628       0.9841       0.0745
#
#                       min          avg          max          std
#     recall :       0.5222       0.8012       0.9836       0.0875
#
#                       min          avg          max          std
#   f1-score :       0.5222       0.7734       0.9292       0.0718
#
#                       min          avg          max          std
#   accuracy :       0.8235       0.9088       0.9706       0.0305
#
#                       min          avg          max          std
#        auc :       0.7904       0.9335       0.9988       0.0393
#
#                       min          avg          max          std
#     g-mean :       0.3589       0.7811       0.9835       0.1117
#
#
# +++ baseline +++
#
#              min_precision avg_precision max_precision std_precision
#           -1       0.9077       0.9460       0.9839       0.0182
#            1       0.3333       0.7569       1.0000       0.1803
#
#                min_recall   avg_recall   max_recall   std_recall
#           -1       0.9180       0.9780       1.0000       0.0192
#            1       0.1429       0.5100       0.8571       0.1750
#
#              min_f1-score avg_f1-score max_f1-score std_f1-score
#           -1       0.9333       0.9616       0.9919       0.0126
#            1       0.2000       0.5880       0.9231       0.1533
#
#                       min          avg          max          std
#  precision :       0.6205       0.8515       0.9919       0.0925
#
#                       min          avg          max          std
#     recall :       0.5550       0.7440       0.9286       0.0865
#
#                       min          avg          max          std
#   f1-score :       0.5683       0.7748       0.9575       0.0821
#
#                       min          avg          max          std
#   accuracy :       0.8824       0.9299       0.9853       0.0229
#
#                       min          avg          max          std
#        auc :       0.7892       0.9329       0.9965       0.0433
#
#                       min          avg          max          std
#     g-mean :       0.3717       0.6945       0.9258       0.1270
