# %% [markdown]
# # **Results for Optical Digits dataset**

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))
from comparator import *

dataset_name = "optical_digits"

# %% [markdown]
# ## Sampling rate = 0.5

# %%
comparator = Comparator(dataset_names=[dataset_name],
                        results_path=f"../results_csv/{dataset_name}.csv",
                        n_trees=100,
                        iterations=100)
comparator.compute()
# Out:
# =========================================================================
# =========================     START COMPUTING     =======================
# =========================================================================
#
# Datasets: ['optical_digits']
# Mode: both
# Oversampling strategies: ['random', 'SMOTE', 'BorderlineSMOTE', 'ADASYN']
# Metrics: ['precision', 'recall', 'f1-score', 'accuracy', 'auc', 'g-mean']
# Iterations: 100
# Number of trees: 100
#
#
#  + DATASET: optical_digits
#
# -=-=-=-=-=-=   BAGGING   =-=-=-=-=-
# random - bagging |██████████████████████████████| 100.0% Complete
# SMOTE - bagging |██████████████████████████████| 100.0% Complete
# BorderlineSMOTE - bagging |██████████████████████████████| 100.0% Complete
# ADASYN - bagging |██████████████████████████████| 100.0% Complete
#
# -=-=-=-=-=-=   AUGMENTATION   =-=-=-=-=-
# random - augmentation |██████████████████████████████| 100.0% Complete
# SMOTE - augmentation |██████████████████████████████| 100.0% Complete
# BorderlineSMOTE - augmentation |██████████████████████████████| 100.0% Complete
# ADASYN - augmentation |██████████████████████████████| 100.0% Complete
#
# -=-=-=-=-=-=   BASELINE   =-=-=-=-=-
# baseline |██████████████████████████████| 100.0% Complete
#
# =========================================================================
# ==================     COMPUTING ENDED SUCCESSFULLY      ================
# =========================================================================

# %%
comparator.summary()
# Out:
#  =========================================================================
# =========================         SUMMARY         =======================
# =========================================================================
#
# *****  DATASET: optical_digits
#
# *****  oversampling rate: 0.5

# %%
comparator.summary(plot_data=True, plot_metrix=False)
# Out:
#  =========================================================================
# =========================         SUMMARY         =======================
# =========================================================================
#
# *****  DATASET: optical_digits
#
# *****  oversampling rate: 0.5
# Class -1 has 4053 points.
# Class 1 has 443 points.
#
#
#
#
# +++ random - bagging
# Class 0 has 4044 original samples and 0 synthetic samples after random bagging.
# Class 1 has 452 original samples and 1570 synthetic samples after random bagging.
#
#
#              min_precision avg_precision max_precision std_precision
#           -1       0.9778       0.9823       0.9864       0.0017
#            1       0.9889       0.9940       1.0000       0.0053
#
#                min_recall   avg_recall   max_recall   std_recall
#           -1       0.9990       0.9994       1.0000       0.0005
#            1       0.7928       0.8353       0.8739       0.0163
#
#              min_f1-score avg_f1-score max_f1-score std_f1-score
#           -1       0.9888       0.9908       0.9927       0.0009
#            1       0.8844       0.9077       0.9282       0.0096
#
#                       min          avg          max          std
#  precision :       0.9838       0.9882       0.9927       0.0027
#
#                       min          avg          max          std
#     recall :       0.8964       0.9174       0.9364       0.0081
#
#                       min          avg          max          std
#   f1-score :       0.9366       0.9492       0.9604       0.0052
#
#                       min          avg          max          std
#   accuracy :       0.9795       0.9832       0.9867       0.0016
#
#                       min          avg          max          std
#        auc :       0.9989       0.9993       0.9996       0.0001
#
#                       min          avg          max          std
#     g-mean :       0.8904       0.9137       0.9344       0.0089
#
#
#
# +++ SMOTE - bagging
# Class 0 has 4057 original samples and 0 synthetic samples after SMOTE bagging.
# Class 1 has 439 original samples and 1589 synthetic samples after SMOTE bagging.
#
#
#              min_precision avg_precision max_precision std_precision
#           -1       0.9825       0.9863       0.9902       0.0014
#            1       0.9796       0.9928       1.0000       0.0051
#
#                min_recall   avg_recall   max_recall   std_recall
#           -1       0.9980       0.9993       1.0000       0.0005
#            1       0.8378       0.8732       0.9099       0.0136
#
#              min_f1-score avg_f1-score max_f1-score std_f1-score
#           -1       0.9907       0.9928       0.9946       0.0008
#            1       0.9073       0.9291       0.9484       0.0081
#
#                       min          avg          max          std
#  precision :       0.9825       0.9895       0.9946       0.0027
#
#                       min          avg          max          std
#     recall :       0.9184       0.9363       0.9545       0.0068
#
#                       min          avg          max          std
#   f1-score :       0.9490       0.9609       0.9715       0.0044
#
#                       min          avg          max          std
#   accuracy :       0.9831       0.9869       0.9902       0.0014
#
#                       min          avg          max          std
#        auc :       0.9990       0.9994       0.9996       0.0001
#
#                       min          avg          max          std
#     g-mean :       0.9149       0.9341       0.9534       0.0073
#
#
#
# +++ BorderlineSMOTE - bagging
# Class 0 has 4061 original samples and 0 synthetic samples after BorderlineSMOTE bagging.
# Class 1 has 435 original samples and 1595 synthetic samples after BorderlineSMOTE bagging.
#
#
#              min_precision avg_precision max_precision std_precision
#           -1       0.9778       0.9831       0.9883       0.0017
#            1       0.9891       0.9996       1.0000       0.0021
#
#                min_recall   avg_recall   max_recall   std_recall
#           -1       0.9990       1.0000       1.0000       0.0002
#            1       0.7928       0.8428       0.8919       0.0160
#
#              min_f1-score avg_f1-score max_f1-score std_f1-score
#           -1       0.9888       0.9914       0.9941       0.0009
#            1       0.8844       0.9144       0.9429       0.0094
#
#                       min          avg          max          std
#  precision :       0.9849       0.9913       0.9941       0.0013
#
#                       min          avg          max          std
#     recall :       0.8964       0.9214       0.9459       0.0080
#
#                       min          avg          max          std
#   f1-score :       0.9366       0.9529       0.9685       0.0051
#
#                       min          avg          max          std
#   accuracy :       0.9795       0.9844       0.9893       0.0016
#
#                       min          avg          max          std
#        auc :       0.9991       0.9995       0.9998       0.0001
#
#                       min          avg          max          std
#     g-mean :       0.8904       0.9180       0.9444       0.0087
#
#
#
# +++ ADASYN - bagging
# Class 0 has 4027 original samples and 0 synthetic samples after ADASYN bagging.
# Class 1 has 469 original samples and 1544 synthetic samples after ADASYN bagging.
#
#
#              min_precision avg_precision max_precision std_precision
#           -1       0.9787       0.9841       0.9883       0.0016
#            1       0.9892       0.9974       1.0000       0.0046
#
#                min_recall   avg_recall   max_recall   std_recall
#           -1       0.9990       0.9998       1.0000       0.0004
#            1       0.8018       0.8526       0.8919       0.0151
#
#              min_f1-score avg_f1-score max_f1-score std_f1-score
#           -1       0.9893       0.9919       0.9941       0.0009
#            1       0.8900       0.9193       0.9429       0.0092
#
#                       min          avg          max          std
#  precision :       0.9854       0.9907       0.9941       0.0025
#
#                       min          avg          max          std
#     recall :       0.9009       0.9262       0.9459       0.0076
#
#                       min          avg          max          std
#   f1-score :       0.9396       0.9556       0.9685       0.0050
#
#                       min          avg          max          std
#   accuracy :       0.9804       0.9852       0.9893       0.0016
#
#                       min          avg          max          std
#        auc :       0.9992       0.9995       0.9998       0.0001
#
#                       min          avg          max          std
#     g-mean :       0.8954       0.9232       0.9444       0.0082
#
#
# +++ random - augmentation +++
# Forest index: 400
# Class -1 has 4053 original points and 0 synthetic points after random augmentation.
# Class 1 has 443 original points and 1583 synthetic points after random augmentation.
#
#
#              min_precision avg_precision max_precision std_precision
#           -1       0.9854       0.9889       0.9912       0.0011
#            1       0.9897       0.9903       1.0000       0.0014
#
#                min_recall   avg_recall   max_recall   std_recall
#           -1       0.9990       0.9990       1.0000       0.0001
#            1       0.8649       0.8973       0.9189       0.0106
#
#              min_f1-score avg_f1-score max_f1-score std_f1-score
#           -1       0.9922       0.9939       0.9951       0.0006
#            1       0.9231       0.9415       0.9533       0.0060
#
#                       min          avg          max          std
#  precision :       0.9875       0.9896       0.9951       0.0010
#
#                       min          avg          max          std
#     recall :       0.9319       0.9482       0.9590       0.0053
#
#                       min          avg          max          std
#   f1-score :       0.9576       0.9677       0.9742       0.0033
#
#                       min          avg          max          std
#   accuracy :       0.9858       0.9890       0.9911       0.0011
#
#                       min          avg          max          std
#        auc :       0.9991       0.9994       0.9997       0.0001
#
#                       min          avg          max          std
#     g-mean :       0.9295       0.9468       0.9581       0.0056
#
#
# +++ SMOTE - augmentation +++
# Forest index: 500
# Class -1 has 4053 original points and 0 synthetic points after SMOTE augmentation.
# Class 1 has 443 original points and 1583 synthetic points after SMOTE augmentation.
#
#
#              min_precision avg_precision max_precision std_precision
#           -1       0.9854       0.9882       0.9912       0.0014
#            1       0.9800       0.9901       1.0000       0.0017
#
#                min_recall   avg_recall   max_recall   std_recall
#           -1       0.9980       0.9990       1.0000       0.0002
#            1       0.8649       0.8909       0.9189       0.0133
#
#              min_f1-score avg_f1-score max_f1-score std_f1-score
#           -1       0.9922       0.9936       0.9951       0.0007
#            1       0.9231       0.9378       0.9533       0.0076
#
#                       min          avg          max          std
#  precision :       0.9837       0.9891       0.9951       0.0013
#
#                       min          avg          max          std
#     recall :       0.9319       0.9450       0.9590       0.0067
#
#                       min          avg          max          std
#   f1-score :       0.9576       0.9657       0.9742       0.0042
#
#                       min          avg          max          std
#   accuracy :       0.9858       0.9883       0.9911       0.0013
#
#                       min          avg          max          std
#        auc :       0.9989       0.9994       0.9997       0.0002
#
#                       min          avg          max          std
#     g-mean :       0.9295       0.9434       0.9581       0.0071
#
#
# +++ BorderlineSMOTE - augmentation +++
# Forest index: 600
# Class -1 has 4053 original points and 0 synthetic points after BorderlineSMOTE augmentation.
# Class 1 has 443 original points and 1583 synthetic points after BorderlineSMOTE augmentation.
#
#
#              min_precision avg_precision max_precision std_precision
#           -1       0.9797       0.9842       0.9883       0.0017
#            1       0.9798       0.9984       1.0000       0.0040
#
#                min_recall   avg_recall   max_recall   std_recall
#           -1       0.9980       0.9999       1.0000       0.0004
#            1       0.8108       0.8534       0.8919       0.0156
#
#              min_f1-score avg_f1-score max_f1-score std_f1-score
#           -1       0.9897       0.9920       0.9941       0.0008
#            1       0.8955       0.9202       0.9429       0.0090
#
#                       min          avg          max          std
#  precision :       0.9831       0.9913       0.9941       0.0020
#
#                       min          avg          max          std
#     recall :       0.9054       0.9266       0.9459       0.0078
#
#                       min          avg          max          std
#   f1-score :       0.9426       0.9561       0.9685       0.0049
#
#                       min          avg          max          std
#   accuracy :       0.9813       0.9854       0.9893       0.0015
#
#                       min          avg          max          std
#        auc :       0.9989       0.9994       0.9997       0.0001
#
#                       min          avg          max          std
#     g-mean :       0.9005       0.9237       0.9444       0.0084
#
#
# +++ ADASYN - augmentation +++
# Forest index: 700
# Class -1 has 4053 original points and 0 synthetic points after ADASYN augmentation.
# Class 1 has 443 original points and 1581 synthetic points after ADASYN augmentation.
#
#
#              min_precision avg_precision max_precision std_precision
#           -1       0.9816       0.9860       0.9902       0.0015
#            1       0.9796       0.9925       1.0000       0.0048
#
#                min_recall   avg_recall   max_recall   std_recall
#           -1       0.9980       0.9993       1.0000       0.0005
#            1       0.8288       0.8707       0.9099       0.0145
#
#              min_f1-score avg_f1-score max_f1-score std_f1-score
#           -1       0.9907       0.9926       0.9946       0.0008
#            1       0.9064       0.9276       0.9484       0.0085
#
#                       min          avg          max          std
#  precision :       0.9825       0.9893       0.9941       0.0025
#
#                       min          avg          max          std
#     recall :       0.9144       0.9350       0.9545       0.0072
#
#                       min          avg          max          std
#   f1-score :       0.9486       0.9601       0.9715       0.0046
#
#                       min          avg          max          std
#   accuracy :       0.9831       0.9866       0.9902       0.0015
#
#                       min          avg          max          std
#        auc :       0.9990       0.9994       0.9998       0.0002
#
#                       min          avg          max          std
#     g-mean :       0.9104       0.9328       0.9534       0.0078
#
#
# +++ baseline +++
#
#              min_precision avg_precision max_precision std_precision
#           -1       0.9769       0.9818       0.9854       0.0017
#            1       0.9891       0.9990       1.0000       0.0031
#
#                min_recall   avg_recall   max_recall   std_recall
#           -1       0.9990       0.9999       1.0000       0.0003
#            1       0.7838       0.8312       0.8649       0.0164
#
#              min_f1-score avg_f1-score max_f1-score std_f1-score
#           -1       0.9883       0.9908       0.9927       0.0009
#            1       0.8788       0.9073       0.9275       0.0098
#
#                       min          avg          max          std
#  precision :       0.9849       0.9904       0.9927       0.0017
#
#                       min          avg          max          std
#     recall :       0.8919       0.9155       0.9324       0.0082
#
#                       min          avg          max          std
#   f1-score :       0.9335       0.9491       0.9601       0.0054
#
#                       min          avg          max          std
#   accuracy :       0.9786       0.9832       0.9867       0.0016
#
#                       min          avg          max          std
#        auc :       0.9988       0.9993       0.9996       0.0001
#
#                       min          avg          max          std
#     g-mean :       0.8853       0.9116       0.9300       0.0090

# %% [markdown]
# ### Sampling rate = 0.3

# %%
comparator1 = Comparator(
    dataset_names=[dataset_name],
    results_path=f"../results_csv/{dataset_name}1.csv",
    sampling_rate=0.3,
    n_trees=100,
    iterations=100,
)
comparator1.compute()
comparator1.summary()
# Out:
# =========================================================================
# =========================     START COMPUTING     =======================
# =========================================================================
#
# Datasets: ['optical_digits']
# Mode: both
# Oversampling strategies: ['random', 'SMOTE', 'BorderlineSMOTE', 'ADASYN']
# Metrics: ['precision', 'recall', 'f1-score', 'accuracy', 'auc', 'g-mean']
# Iterations: 100
# Number of trees: 100
#
#
#  + DATASET: optical_digits
#
# -=-=-=-=-=-=   BAGGING   =-=-=-=-=-
# random - bagging |██████████████████████████████| 100.0% Complete
# SMOTE - bagging |██████████████████████████████| 100.0% Complete
# BorderlineSMOTE - bagging |██████████████████████████████| 100.0% Complete
# ADASYN - bagging |██████████████████████████████| 100.0% Complete
#
# -=-=-=-=-=-=   AUGMENTATION   =-=-=-=-=-
# random - augmentation |██████████████████████████████| 100.0% Complete
# SMOTE - augmentation |██████████████████████████████| 100.0% Complete
# BorderlineSMOTE - augmentation |██████████████████████████████| 100.0% Complete
# ADASYN - augmentation |██████████████████████████████| 100.0% Complete
#
# -=-=-=-=-=-=   BASELINE   =-=-=-=-=-
# baseline |██████████████████████████████| 100.0% Complete
#
# =========================================================================
# ==================     COMPUTING ENDED SUCCESSFULLY      ================
# =========================================================================
#
#
#  =========================================================================
# =========================         SUMMARY         =======================
# =========================================================================
#
# *****  DATASET: optical_digits
#
# *****  oversampling rate: 0.3

# %%
comparator2 = Comparator(
    dataset_names=[dataset_name],
    results_path=f"../results_csv/{dataset_name}2.csv",
    sampling_rate=0.7,
    n_trees=100,
    iterations=100,
)

comparator2.compute()
comparator2.summary()
# Out:
# =========================================================================
# =========================     START COMPUTING     =======================
# =========================================================================
#
# Datasets: ['optical_digits']
# Mode: both
# Oversampling strategies: ['random', 'SMOTE', 'BorderlineSMOTE', 'ADASYN']
# Metrics: ['precision', 'recall', 'f1-score', 'accuracy', 'auc', 'g-mean']
# Iterations: 100
# Number of trees: 100
#
#
#  + DATASET: optical_digits
#
# -=-=-=-=-=-=   BAGGING   =-=-=-=-=-
# random - bagging |██████████████████████████████| 100.0% Complete
# SMOTE - bagging |██████████████████████████████| 100.0% Complete
# BorderlineSMOTE - bagging |██████████████████████████████| 100.0% Complete
# ADASYN - bagging |██████████████████████████████| 100.0% Complete
#
# -=-=-=-=-=-=   AUGMENTATION   =-=-=-=-=-
# random - augmentation |██████████████████████████████| 100.0% Complete
# SMOTE - augmentation |██████████████████████████████| 100.0% Complete
# BorderlineSMOTE - augmentation |██████████████████████████████| 100.0% Complete
# ADASYN - augmentation |██████████████████████████████| 100.0% Complete
#
# -=-=-=-=-=-=   BASELINE   =-=-=-=-=-
# baseline |██████████████████████████████| 100.0% Complete
#
# =========================================================================
# ==================     COMPUTING ENDED SUCCESSFULLY      ================
# =========================================================================
#
#
#  =========================================================================
# =========================         SUMMARY         =======================
# =========================================================================
#
# *****  DATASET: optical_digits
#
# *****  oversampling rate: 0.7
