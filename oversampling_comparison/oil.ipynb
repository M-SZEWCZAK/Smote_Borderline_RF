# %% [markdown]
# # **Results for Oil dataset**

# %%
import sys
import os

sys.path.append(os.path.abspath(".."))
from comparator import *

dataset_name = "oil"

# %% [markdown]
# ## Sampling rate = 0.5

# %%
comparator = Comparator(dataset_names=[dataset_name],
                        results_path=f"../results_csv/{dataset_name}.csv",
                        n_trees=100,
                        iterations=100)
comparator.compute()
# Out:
# =========================================================================
# =========================     START COMPUTING     =======================
# =========================================================================
#
# Datasets: ['oil']
# Mode: both
# Oversampling strategies: ['random', 'SMOTE', 'BorderlineSMOTE', 'ADASYN']
# Metrics: ['precision', 'recall', 'f1-score', 'accuracy', 'auc', 'g-mean']
# Iterations: 100
# Number of trees: 100
#
#
#  + DATASET: oil
#
# -=-=-=-=-=-=   BAGGING   =-=-=-=-=-
# random - bagging |██████████████████████████████| 100.0% Complete
# SMOTE - bagging |██████████████████████████████| 100.0% Complete
# BorderlineSMOTE - bagging |██████████████████████████████| 100.0% Complete
# ADASYN - bagging |██████████████████████████████| 100.0% Complete
#
# -=-=-=-=-=-=   AUGMENTATION   =-=-=-=-=-
# random - augmentation |██████████████████████████████| 100.0% Complete
# SMOTE - augmentation |██████████████████████████████| 100.0% Complete
# BorderlineSMOTE - augmentation |██████████████████████████████| 100.0% Complete
# ADASYN - augmentation |██████████████████████████████| 100.0% Complete
#
# -=-=-=-=-=-=   BASELINE   =-=-=-=-=-
# baseline |██████████████████████████████| 100.0% Complete
#
# =========================================================================
# ==================     COMPUTING ENDED SUCCESSFULLY      ================
# =========================================================================

# %%
comparator.summary()
# Out:
#  =========================================================================
# =========================         SUMMARY         =======================
# =========================================================================
#
# *****  DATASET: oil
#
# *****  oversampling rate: 0.5

# %% [markdown]
# ### Sampling rate = 0.3

# %%
comparator1 = Comparator(
    dataset_names=[dataset_name],
    results_path=f"../results_csv/{dataset_name}1.csv",
    sampling_rate=0.3,
    n_trees=100,
    iterations=100,
)
comparator1.compute()
comparator1.summary()
# Out:
# =========================================================================
# =========================     START COMPUTING     =======================
# =========================================================================
#
# Datasets: ['oil']
# Mode: both
# Oversampling strategies: ['random', 'SMOTE', 'BorderlineSMOTE', 'ADASYN']
# Metrics: ['precision', 'recall', 'f1-score', 'accuracy', 'auc', 'g-mean']
# Iterations: 100
# Number of trees: 100
#
#
#  + DATASET: oil
#
# -=-=-=-=-=-=   BAGGING   =-=-=-=-=-
# random - bagging |██████████████████████████████| 100.0% Complete
# SMOTE - bagging |██████████████████████████████| 100.0% Complete
# BorderlineSMOTE - bagging |██████████████████████████████| 100.0% Complete
# ADASYN - bagging |██████████████████████████████| 100.0% Complete
#
# -=-=-=-=-=-=   AUGMENTATION   =-=-=-=-=-
# random - augmentation |██████████████████████████████| 100.0% Complete
# SMOTE - augmentation |██████████████████████████████| 100.0% Complete
# BorderlineSMOTE - augmentation |██████████████████████████████| 100.0% Complete
# ADASYN - augmentation |██████████████████████████████| 100.0% Complete
#
# -=-=-=-=-=-=   BASELINE   =-=-=-=-=-
# baseline |██████████████████████████████| 100.0% Complete
#
# =========================================================================
# ==================     COMPUTING ENDED SUCCESSFULLY      ================
# =========================================================================
#
#
#  =========================================================================
# =========================         SUMMARY         =======================
# =========================================================================
#
# *****  DATASET: oil
#
# *****  oversampling rate: 0.3

# %%
comparator2 = Comparator(
    dataset_names=[dataset_name],
    results_path=f"../results_csv/{dataset_name}2.csv",
    sampling_rate=0.15,
    n_trees=100,
    iterations=100,
)

comparator2.compute()
comparator2.summary()
# Out:
# =========================================================================
# =========================     START COMPUTING     =======================
# =========================================================================
#
# Datasets: ['oil']
# Mode: both
# Oversampling strategies: ['random', 'SMOTE', 'BorderlineSMOTE', 'ADASYN']
# Metrics: ['precision', 'recall', 'f1-score', 'accuracy', 'auc', 'g-mean']
# Iterations: 100
# Number of trees: 100
#
#
#  + DATASET: oil
#
# -=-=-=-=-=-=   BAGGING   =-=-=-=-=-
# random - bagging |██████████████████████████████| 100.0% Complete
# SMOTE - bagging |██████████████████████████████| 100.0% Complete
# BorderlineSMOTE - bagging |██████████████████████████████| 100.0% Complete
# ADASYN - bagging |██████████████████████████████| 100.0% Complete
#
# -=-=-=-=-=-=   AUGMENTATION   =-=-=-=-=-
# random - augmentation |██████████████████████████████| 100.0% Complete
# SMOTE - augmentation |██████████████████████████████| 100.0% Complete
# BorderlineSMOTE - augmentation |██████████████████████████████| 100.0% Complete
# ADASYN - augmentation |██████████████████████████████| 100.0% Complete
#
# -=-=-=-=-=-=   BASELINE   =-=-=-=-=-
# baseline |██████████████████████████████| 100.0% Complete
#
# =========================================================================
# ==================     COMPUTING ENDED SUCCESSFULLY      ================
# =========================================================================
#
#
#  =========================================================================
# =========================         SUMMARY         =======================
# =========================================================================
#
# *****  DATASET: oil
#
# *****  oversampling rate: 0.15

# %%
comparator.summary(plot_data=True, plot_metrix=False)
# Out:
#  =========================================================================
# =========================         SUMMARY         =======================
# =========================================================================
#
# *****  DATASET: oil
#
# *****  oversampling rate: 0.5
# Class -1 has 716 points.
# Class 1 has 33 points.
#
#
#
#
# +++ random - bagging
# Class 0 has 711 original samples and 0 synthetic samples after random bagging.
# Class 1 has 38 original samples and 317 synthetic samples after random bagging.
#
#
#              min_precision avg_precision max_precision std_precision
#           -1       0.9572       0.9642       0.9783       0.0050
#            1       0.0000       0.6525       1.0000       0.3856
#
#                min_recall   avg_recall   max_recall   std_recall
#           -1       0.9778       0.9974       1.0000       0.0040
#            1       0.0000       0.1650       0.5000       0.1203
#
#              min_f1-score avg_f1-score max_f1-score std_f1-score
#           -1       0.9724       0.9805       0.9890       0.0031
#            1       0.0000       0.2531       0.6667       0.1676
#
#                       min          avg          max          std
#  precision :       0.4786       0.8083       0.9891       0.1944
#
#                       min          avg          max          std
#     recall :       0.4972       0.5812       0.7500       0.0599
#
#                       min          avg          max          std
#   f1-score :       0.4877       0.6168       0.8278       0.0851
#
#                       min          avg          max          std
#   accuracy :       0.9468       0.9620       0.9787       0.0060
#
#                       min          avg          max          std
#        auc :       0.7819       0.9387       1.0000       0.0385
#
#                       min          avg          max          std
#     g-mean :       0.0000       0.3554       0.7071       0.1964
#
#
#
# +++ SMOTE - bagging
# Class 0 has 719 original samples and 0 synthetic samples after SMOTE bagging.
# Class 1 has 30 original samples and 329 synthetic samples after SMOTE bagging.
#
#
#              min_precision avg_precision max_precision std_precision
#           -1       0.9620       0.9726       0.9890       0.0071
#            1       0.2500       0.7515       1.0000       0.2065
#
#                min_recall   avg_recall   max_recall   std_recall
#           -1       0.9722       0.9937       1.0000       0.0057
#            1       0.1250       0.3688       0.7500       0.1670
#
#              min_f1-score avg_f1-score max_f1-score std_f1-score
#           -1       0.9724       0.9830       0.9917       0.0043
#            1       0.1667       0.4720       0.8000       0.1672
#
#                       min          avg          max          std
#  precision :       0.6060       0.8620       0.9918       0.1042
#
#                       min          avg          max          std
#     recall :       0.5542       0.6812       0.8722       0.0832
#
#                       min          avg          max          std
#   f1-score :       0.5696       0.7275       0.8958       0.0855
#
#                       min          avg          max          std
#   accuracy :       0.9468       0.9671       0.9840       0.0083
#
#                       min          avg          max          std
#        auc :       0.7889       0.9520       0.9958       0.0336
#
#                       min          avg          max          std
#     g-mean :       0.3506       0.5884       0.8636       0.1423
#
#
#
# +++ BorderlineSMOTE - bagging
# Class 0 has 711 original samples and 0 synthetic samples after BorderlineSMOTE bagging.
# Class 1 has 38 original samples and 317 synthetic samples after BorderlineSMOTE bagging.
#
#
#              min_precision avg_precision max_precision std_precision
#           -1       0.9574       0.9716       0.9889       0.0063
#            1       0.0000       0.7896       1.0000       0.2101
#
#                min_recall   avg_recall   max_recall   std_recall
#           -1       0.9778       0.9954       1.0000       0.0047
#            1       0.0000       0.3450       0.7500       0.1498
#
#              min_f1-score avg_f1-score max_f1-score std_f1-score
#           -1       0.9724       0.9834       0.9917       0.0038
#            1       0.0000       0.4622       0.7692       0.1569
#
#                       min          avg          max          std
#  precision :       0.4787       0.8806       0.9918       0.1060
#
#                       min          avg          max          std
#     recall :       0.5000       0.6702       0.8694       0.0747
#
#                       min          avg          max          std
#   f1-score :       0.4891       0.7228       0.8805       0.0801
#
#                       min          avg          max          std
#   accuracy :       0.9468       0.9678       0.9840       0.0074
#
#                       min          avg          max          std
#        auc :       0.8146       0.9436       0.9938       0.0387
#
#                       min          avg          max          std
#     g-mean :       0.0000       0.5699       0.8612       0.1370
#
#
#
# +++ ADASYN - bagging
# Class 0 has 717 original samples and 0 synthetic samples after ADASYN bagging.
# Class 1 has 32 original samples and 333 synthetic samples after ADASYN bagging.
#
#
#              min_precision avg_precision max_precision std_precision
#           -1       0.9570       0.9733       0.9836       0.0066
#            1       0.0000       0.7496       1.0000       0.2553
#
#                min_recall   avg_recall   max_recall   std_recall
#           -1       0.9722       0.9943       1.0000       0.0059
#            1       0.0000       0.3850       0.6250       0.1566
#
#              min_f1-score avg_f1-score max_f1-score std_f1-score
#           -1       0.9724       0.9837       0.9917       0.0046
#            1       0.0000       0.4957       0.7692       0.1768
#
#                       min          avg          max          std
#  precision :       0.4785       0.8614       0.9918       0.1296
#
#                       min          avg          max          std
#     recall :       0.4944       0.6896       0.8125       0.0785
#
#                       min          avg          max          std
#   f1-score :       0.4863       0.7397       0.8805       0.0905
#
#                       min          avg          max          std
#   accuracy :       0.9468       0.9684       0.9840       0.0090
#
#                       min          avg          max          std
#        auc :       0.8653       0.9552       0.9990       0.0283
#
#                       min          avg          max          std
#     g-mean :       0.0000       0.5959       0.7906       0.1673
#
#
# +++ random - augmentation +++
# Forest index: 400
# Class -1 has 716 original points and 0 synthetic points after random augmentation.
# Class 1 has 33 original points and 325 synthetic points after random augmentation.
#
#
#              min_precision avg_precision max_precision std_precision
#           -1       0.9568       0.9704       0.9889       0.0066
#            1       0.0000       0.7087       1.0000       0.2829
#
#                min_recall   avg_recall   max_recall   std_recall
#           -1       0.9611       0.9934       1.0000       0.0072
#            1       0.0000       0.3162       0.7500       0.1553
#
#              min_f1-score avg_f1-score max_f1-score std_f1-score
#           -1       0.9665       0.9817       0.9917       0.0050
#            1       0.0000       0.4189       0.7692       0.1762
#
#                       min          avg          max          std
#  precision :       0.4784       0.8395       0.9918       0.1430
#
#                       min          avg          max          std
#     recall :       0.4917       0.6548       0.8694       0.0778
#
#                       min          avg          max          std
#   f1-score :       0.4849       0.7003       0.8805       0.0901
#
#                       min          avg          max          std
#   accuracy :       0.9362       0.9646       0.9840       0.0096
#
#                       min          avg          max          std
#        auc :       0.7979       0.9415       0.9969       0.0442
#
#                       min          avg          max          std
#     g-mean :       0.0000       0.5337       0.8612       0.1721
#
#
# +++ SMOTE - augmentation +++
# Forest index: 500
# Class -1 has 716 original points and 0 synthetic points after SMOTE augmentation.
# Class 1 has 33 original points and 325 synthetic points after SMOTE augmentation.
#
#
#              min_precision avg_precision max_precision std_precision
#           -1       0.9570       0.9776       0.9945       0.0077
#            1       0.0000       0.7399       1.0000       0.1992
#
#                min_recall   avg_recall   max_recall   std_recall
#           -1       0.9667       0.9913       1.0000       0.0075
#            1       0.0000       0.4863       0.8750       0.1802
#
#              min_f1-score avg_f1-score max_f1-score std_f1-score
#           -1       0.9721       0.9844       0.9972       0.0049
#            1       0.0000       0.5640       0.9333       0.1673
#
#                       min          avg          max          std
#  precision :       0.4785       0.8587       0.9972       0.1007
#
#                       min          avg          max          std
#     recall :       0.4944       0.7388       0.9375       0.0894
#
#                       min          avg          max          std
#   f1-score :       0.4863       0.7742       0.9653       0.0857
#
#                       min          avg          max          std
#   accuracy :       0.9468       0.9698       0.9947       0.0094
#
#                       min          avg          max          std
#        auc :       0.8632       0.9534       0.9934       0.0298
#
#                       min          avg          max          std
#     g-mean :       0.0000       0.6776       0.9354       0.1512
#
#
# +++ BorderlineSMOTE - augmentation +++
# Forest index: 600
# Class -1 has 716 original points and 0 synthetic points after BorderlineSMOTE augmentation.
# Class 1 has 33 original points and 325 synthetic points after BorderlineSMOTE augmentation.
#
#
#              min_precision avg_precision max_precision std_precision
#           -1       0.9624       0.9770       0.9944       0.0070
#            1       0.4000       0.7082       1.0000       0.1637
#
#                min_recall   avg_recall   max_recall   std_recall
#           -1       0.9722       0.9905       1.0000       0.0065
#            1       0.1250       0.4750       0.8750       0.1648
#
#              min_f1-score avg_f1-score max_f1-score std_f1-score
#           -1       0.9751       0.9837       0.9945       0.0045
#            1       0.2000       0.5515       0.8750       0.1445
#
#                       min          avg          max          std
#  precision :       0.6836       0.8426       0.9945       0.0829
#
#                       min          avg          max          std
#     recall :       0.5597       0.7327       0.9347       0.0820
#
#                       min          avg          max          std
#   f1-score :       0.5891       0.7676       0.9347       0.0742
#
#                       min          avg          max          std
#   accuracy :       0.9521       0.9686       0.9894       0.0087
#
#                       min          avg          max          std
#        auc :       0.8535       0.9455       0.9941       0.0282
#
#                       min          avg          max          std
#     g-mean :       0.3526       0.6749       0.9328       0.1225
#
#
# +++ ADASYN - augmentation +++
# Forest index: 700
# Class -1 has 716 original points and 0 synthetic points after ADASYN augmentation.
# Class 1 has 33 original points and 325 synthetic points after ADASYN augmentation.
#
#
#              min_precision avg_precision max_precision std_precision
#           -1       0.9624       0.9783       0.9944       0.0069
#            1       0.4000       0.7446       1.0000       0.1572
#
#                min_recall   avg_recall   max_recall   std_recall
#           -1       0.9667       0.9915       1.0000       0.0065
#            1       0.1250       0.5038       0.8750       0.1623
#
#              min_f1-score avg_f1-score max_f1-score std_f1-score
#           -1       0.9752       0.9848       0.9945       0.0043
#            1       0.2000       0.5837       0.8571       0.1413
#
#                       min          avg          max          std
#  precision :       0.6836       0.8614       0.9945       0.0795
#
#                       min          avg          max          std
#     recall :       0.5597       0.7476       0.9319       0.0805
#
#                       min          avg          max          std
#   f1-score :       0.5891       0.7843       0.9258       0.0725
#
#                       min          avg          max          std
#   accuracy :       0.9521       0.9707       0.9894       0.0082
#
#                       min          avg          max          std
#        auc :       0.8128       0.9476       0.9962       0.0393
#
#                       min          avg          max          std
#     g-mean :       0.3526       0.6964       0.9302       0.1203
#
#
# +++ baseline +++
#
#              min_precision avg_precision max_precision std_precision
#           -1       0.9570       0.9681       0.9836       0.0062
#            1       0.0000       0.7445       1.0000       0.3115
#
#                min_recall   avg_recall   max_recall   std_recall
#           -1       0.9778       0.9959       1.0000       0.0053
#            1       0.0000       0.2612       0.6250       0.1477
#
#              min_f1-score avg_f1-score max_f1-score std_f1-score
#           -1       0.9724       0.9818       0.9917       0.0041
#            1       0.0000       0.3685       0.7692       0.1830
#
#                       min          avg          max          std
#  precision :       0.4785       0.8563       0.9918       0.1572
#
#                       min          avg          max          std
#     recall :       0.4944       0.6286       0.8125       0.0738
#
#                       min          avg          max          std
#   f1-score :       0.4863       0.6752       0.8805       0.0932
#
#                       min          avg          max          std
#   accuracy :       0.9468       0.9646       0.9840       0.0079
#
#                       min          avg          max          std
#        auc :       0.7118       0.9255       0.9927       0.0482
#
#                       min          avg          max          std
#     g-mean :       0.0000       0.4757       0.7906       0.1851
